# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Fares Ferreira Pessoa__
#
# I'm a Petroleum Geologist

# %% [markdown]
# _I am interested in find data science applications to solve geological problems_

# %% [markdown]
# ### The code prints the result of a sum 1 + 1

# %%
print("The sum 1 + 1 = {s}".format(s= 1+1))
# Out:
# The sum 1 + 1 = 2

# %% [markdown]
# | Id          |        Name |
# | ----------- | ----------- |
# | 1           | Mark        |
# | 2           | Tom         |
#
# [IBM](https://www.ibm.com/)
#
# * Item 1
# * Item 2
